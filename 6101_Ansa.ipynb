# %% [markdown]
# <a href="https://colab.research.google.com/github/ann77382/Ansa-Mariam/blob/main/6101_Ansa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AMAZON SALES**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("/content/Sales Report.csv")

# %%
df.head()
# Out:
#               Order ID      Date                        Status  \
# 0  405-8078784-5731545  04-30-22                     Cancelled
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2  404-0687676-7273146  04-30-22                       Shipped
# 3  403-9615377-8133951  04-30-22                     Cancelled
# 4  407-1069790-7240320  04-30-22                       Shipped
#
#   ship-service-level    Style       Category Size        ASIN  Qty  Amount  \
# 0           Standard   SET389            Set    S  B09KXVBD7Z    0  647.62
# 1           Standard  JNE3781          kurta  3XL  B09K3WFS32    1  406.00
# 2          Expedited  JNE3371          kurta   XL  B07WV4JV4D    1  329.00
# 3           Standard    J0341  Western Dress    L  B099NRCT7B    0  753.33
# 4          Expedited  JNE3671            Top  3XL  B098714BZP    1  574.00
#
#      ship-city   ship-state  ship-postal-code
# 0       MUMBAI  MAHARASHTRA          400081.0
# ...

# %%
# Display rows
display(df)
# Out:
#                   Order ID      Date                        Status  \
# 0      405-8078784-5731545  04-30-22                     Cancelled
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      404-0687676-7273146  04-30-22                       Shipped
# 3      403-9615377-8133951  04-30-22                     Cancelled
# 4      407-1069790-7240320  04-30-22                       Shipped
# ...                    ...       ...                           ...
# 64473  171-2070798-4305901  05-19-22  Shipped - Delivered to Buyer
# 64474  171-4698648-6044343  05-19-22                       Shipped
# 64475  171-4698648-6044343  05-19-22                       Shipped
# 64476  171-5832528-6113925  05-19-22  Shipped - Delivered to Buyer
# 64477  407-2933661-6388319  05-19-22         Shipped - Delivered t
#
#       ship-service-level    Style       Category Size        ASIN  Qty  \
# 0               Standard   SET389            Set    S  B09KXVBD7Z  0.0
# ...

# %%
# To check number of null values in dataframe
df.isnull().sum()
# Out:
# Order ID                 0
# Date                     0
# Status                   0
# ship-service-level       1
# Style                    1
# Category                 1
# Size                     1
# ASIN                     1
# Qty                      1
# Amount                3886
# ship-city               16
# ship-state              16
# ship-postal-code        16
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64478 entries, 0 to 64477
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            64478 non-null  object
#  1   Date                64478 non-null  object
#  2   Status              64478 non-null  object
#  3   ship-service-level  64477 non-null  object
#  4   Style               64477 non-null  object
#  5   Category            64477 non-null  object
#  6   Size                64477 non-null  object
#  7   ASIN                64477 non-null  object
#  8   Qty                 64477 non-null  float64
#  9   Amount              60592 non-null  float64
#  10  ship-city           64462 non-null  object
#  11  ship-state          64462 non-null  object
#  12  ship-postal-code    64462 non-null  float64
# dtypes: float64(3), object(10)
# memory usage: 6.4+ MB

# %%
df.describe()
# Out:
#                 Qty        Amount  ship-postal-code
# count  64477.000000  60592.000000      64462.000000
# mean       0.904198    638.030250     463882.076184
# std        0.319731    275.964049     193710.597924
# min        0.000000      0.000000     110001.000000
# 25%        1.000000    442.000000     380058.000000
# 50%        1.000000    597.000000     500027.000000
# 75%        1.000000    788.000000     600036.000000
# max       15.000000   5584.000000     989898.000000

# %%
df['Style'].value_counts()
# Out:
# JNE3405    1680
# SET268     1545
# JNE3797    1206
# J0230      1097
# J0341      1049
#            ...
# J0022         1
# JNE2302       1
# BL056         1
# SAR108        1
# SET372        1
# Name: Style, Length: 1271, dtype: int64

# %%
df['ship-state'].unique()
print(df['ship-state'].unique())
df['ship-state'].nunique()
# Out:
# ['MAHARASHTRA' 'KARNATAKA' 'PUDUCHERRY' 'TAMIL NADU' 'UTTAR PRADESH'
#  'CHANDIGARH' 'TELANGANA' 'ANDHRA PRADESH' 'RAJASTHAN' 'DELHI' 'HARYANA'
#  'ASSAM' 'JHARKHAND' 'CHHATTISGARH' 'ODISHA' 'KERALA' 'MADHYA PRADESH'
#  'WEST BENGAL' 'NAGALAND' 'Gujarat' 'UTTARAKHAND' 'BIHAR'
#  'JAMMU & KASHMIR' 'PUNJAB' 'HIMACHAL PRADESH' 'ARUNACHAL PRADESH'
#  'MANIPUR' 'Goa' 'MEGHALAYA' 'GOA' 'TRIPURA' 'LADAKH' 'DADRA AND NAGAR'
#  'SIKKIM' 'Delhi' nan 'ANDAMAN & NICOBAR ' 'Punjab' 'Rajshthan' 'Manipur'
#  'rajasthan' 'Odisha' 'NL' 'Bihar' 'MIZORAM' 'punjab' 'New Delhi'
#  'Rajasthan' 'Punjab/Mohali/Zirakpur' 'Puducherry' 'delhi' 'RJ'
#  'Chandigarh' 'orissa' 'LAKSHADWEEP' 'goa' 'PB' 'APO' 'Arunachal Pradesh'
#  'AR' 'Pondicherry']
# 60

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        Qty    Amount  ship-postal-code
# Qty               1.000000  0.071599         -0.015056
# Amount            0.071599  1.000000         -0.048092
# ship-postal-code -0.015056 -0.048092          1.000000

# %%
df.groupby('ship-state').mean()
# Out:
# <ipython-input-15-22e85454ef12>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('ship-state').mean()
#                              Qty       Amount  ship-postal-code
# ship-state
# ANDAMAN & NICOBAR       0.857143   677.718772     744104.365079
# ANDHRA PRADESH          0.892782   603.166416     524824.840224
# ARUNACHAL PRADESH       0.815789   658.070000     791273.315789
# ASSAM                   0.866019   635.518790     783348.801942
# BIHAR                   0.871118   704.534518     821018.827640
# Bihar                   1.000000   736.666667     817319.416667
# CHANDIGARH              0.941860   655.218214     160034.186047
# CHHATTISGARH            0.916376   637.691799     493390.139373
# Chandigarh              1.000000  1327.500000     160047.000000
# ...

# %%
df.sort_values('Amount',ascending=False)
# Out:
#                   Order ID        Date                        Status  \
# 11160  403-4106553-1691525    04-23-22  Shipped - Delivered to Buyer
# 24494  407-3483041-9133135    04-16-22                     Cancelled
# 28814  408-9885439-6698733    04-13-22                       Shipped
# 16577  405-4362525-1025138    04-20-22                       Shipped
# 20534  406-1124784-1093950    04-18-22  Shipped - Delivered to Buyer
# ...                    ...         ...                           ...
# 36745  406-4539745-7452306  04-08-2022                     Cancelled
# 36746  406-3968259-1306706  04-08-2022                     Cancelled
# 36748  407-8150418-6969943  04-08-2022                     Cancelled
# 36755  406-1168541-6431521  04-08-2022                     Cancelled
# 36761  408-5751415-7088334  04-08-2022                     Cancelled
#
#       ship-service-level    Style       Category Size        ASIN  Qty  \
# ...

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='BuPu')
# Out:
# <ipython-input-12-6967e04ae1a6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %%
df['Size'].value_counts()
# Out:
# M       11210
# L       11096
# XL      10482
# XXL      8932
# S        8663
# 3XL      7541
# XS       5690
# 6XL       267
# Free      233
# 5XL       197
# 4XL       166
# Name: Size, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Size'])
plt.show()

# %% [markdown]
# CONCLUSION:
#
# pair plot: It is commonly used for exploratory data analysis (EDA) to visualize relationships between multiple variables in a
# dataset. It creates a grid of scatter plots and histograms, making it easy to identify patterns, correlations, and potential
# outliers.
#
# Count plot:Count plot is used to know how much the sizes of the dresses is sold so that we can analyze the plot to understand
# the sales based on profit and loss.

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df[['Amount']].head(10).plot(color='Red')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Category'],color='Green')
plt.show()

# %% [markdown]
# Conclusion:
#
# Line plot:Line plot is used to know the highest amount.
#
# Count plot:count plot is used to no which category has the highest sales so that we can be use new strategies to increase the sales of the low sales product.

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
plt.figure(figsize=(8,6))
subset_df = df.head(128976).head(30)
sns.scatterplot(x='Category',y='ship-city',hue='Size',data=subset_df,color='Red')
plt.title('Distribution of City by Category')
plt.xlabel('Category')
plt.ylabel('ship-city')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# CONCLUSION:
#
# Scatter plot: Scatter plot is used to know the highest sales in which Category based on cities between their sizes.

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
# Boxplot for 'Status' vs 'Amount'
plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
sns.boxplot(x='Status', y='Amount', data=subset_df)
plt.title('Status vs Amount')
plt.show()

# %%
# Pairplot for 'Qty', 'Amount', and 'ship-service-level'
sns.pairplot(data_df, hue='ship-service-level', diag_kind='kde')
plt.show()

# %% [markdown]
# Conclusion:
#
# Pairplot:This pair plot visualizes the relationships between the variables 'Qty', 'Amount', and 'ship-service-level'.
# The scatter plots along the diagonal show the distribution of each variable, while the off-diagonal plots show the relationships between them. The hue='ship-service-level' parameter colors the points based on the service level.
# The diagonal also includes Kernel Density Estimation (KDE) plots to visualize the probability density of each variable.
#
# Boxplot for Status vs Amount:This boxplot compares the distribution of 'Amount' for different 'Status' categories.
# It helps us understand the spread and central tendency of the amount for each order status. For example, if there are outliers or significant differences in the medians, it may indicate variations in spending behavior based on order status.
